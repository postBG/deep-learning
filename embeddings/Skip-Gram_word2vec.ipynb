# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the **embedding layer** and the weights are **embedding weights**. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

if not isfile(dataset_filename):
    urlretrieve(
        'http://mattmahoney.net/dc/text8.zip',
        dataset_filename)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

word_counts = Counter(int_words)
word_counts.most_common(3)
# Out:
# [(0, 1061396), (1, 593677), (2, 416629)]

# %%
threshold = 1e-5

total_counts = len(int_words)
frequencies = {word: count / total_counts for word, count in word_counts.items()}
drop_prob = {word: 1 - np.sqrt(threshold / frequencies[word]) for word in int_words}

# %%
drop_prob[0]
# Out:
# 0.98746376577740469

# %%
## Your code here
import random

train_words = [word for word in int_words if drop_prob[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name="inputs")
    labels = tf.placeholder(tf.int32, shape=[None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab])) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6279 0.1003 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6207 0.0964 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5257 0.0969 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6040 0.0982 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5169 0.0995 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5425 0.0966 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5232 0.0968 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5838 0.1032 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4843 0.1032 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4365 0.1069 sec/batch
# Nearest to d: theophylline, musashi, evatt, beaconsfield, acrobat, guido, stara, aboard,
# Nearest to zero: beverages, magistracies, oration, seeking, haar, boers, thrice, regulations,
# Nearest to by: waddingtons, maus, spore, congreve, gin, preset, sim, lipolysis,
# Nearest to up: partitioning, barycenter, bussard, old, zeng, solver, statistically, lichfield,
# Nearest to when: rpgs, berry, chah, merv, genevan, councils, vilhelm, hew,
# Nearest to years: seam, groves, ribald, glenville, chhatro, ldapv, target, thirteen,
# Nearest to between: kvac, fulfill, land, marchand, que, ludovico, fact, meriwether,
# Nearest to time: singly, radiometric, scholarship, emirs, titled, ndor, ladislaus, location,
# Nearest to event: yama, radiant, maurier, reporters, pata, mcmartin, protestors, waitemata,
# Nearest to governor: offending, dashed, staind, accustomed, ammeter, characterises, wb, burdensome,
# Nearest to liberal: amending, redesigned, circumference, degeneracy, carp, dss, capricorn, courtesy,
# Nearest to bbc: coils, italian, motivic, eight, freda, ritually, mmend, homebrew,
# Nearest to file: lahoud, carsten, pluralized, setter, huf, shaker, terrifying, retrofitted,
# Nearest to heavy: seamonkey, boney, zephaniah, life, awt, fades, facie, trapdoor,
# Nearest to taking: quran, conquistadores, hajj, hemorrhage, consonance, grumman, tigre, senegalese,
# Nearest to bible: grandfather, experimenter, newsradio, yana, theban, wortley, reggio, huxley,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4766 0.1103 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3727 0.1093 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3322 0.1126 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2495 0.1127 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1942 0.1133 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1851 0.1128 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0859 0.1136 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0813 0.1146 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0078 0.1137 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9915 0.1142 sec/batch
# Nearest to d: theophylline, beaconsfield, replacing, musashi, surviving, ministry, evatt, guido,
# Nearest to zero: seeking, beverages, oration, magistracies, regulations, talk, drama, clay,
# Nearest to by: raised, spore, stemming, pharmaceutical, gin, sim, academic, maus,
# Nearest to up: old, partitioning, barycenter, why, statistically, redirected, turning, self,
# Nearest to when: rpgs, councils, feet, grant, sent, berry, jon, historians,
# Nearest to years: groves, target, domestic, seam, thirteen, ribald, immediately, metaphysical,
# Nearest to between: fact, fulfill, land, kvac, groups, apart, heavens, mp,
# Nearest to time: location, singly, scholarship, titled, radiometric, question, avoid, explosion,
# Nearest to event: yama, reporters, radiant, maurier, pata, protestors, transmitted, accounts,
# Nearest to governor: offending, dashed, accustomed, person, wb, europe, characterises, en,
# Nearest to liberal: amending, redesigned, circumference, degeneracy, money, neither, bran, activities,
# Nearest to bbc: italian, coils, eight, motivic, ritually, installations, freda, kill,
# Nearest to file: pluralized, lahoud, setter, carsten, sped, shaker, deity, harness,
# Nearest to heavy: life, zephaniah, boney, eyes, disagreements, kinshasa, seamonkey, switches,
# Nearest to taking: quran, conquistadores, represents, hajj, hemorrhage, require, details, exchange,
# Nearest to bible: grandfather, per, experimenter, lost, yana, selected, newsradio, destruction,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9485 0.1155 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8890 0.1150 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8734 0.1152 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8718 0.1159 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8020 0.1159 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8062 0.1156 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7965 0.1177 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7832 0.1166 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7988 0.1164 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7904 0.1164 sec/batch
# Nearest to d: guido, theophylline, aboard, defection, beaconsfield, surviving, musashi, evatt,
# Nearest to zero: beverages, nine, eight, oration, seeking, eu, politician, historian,
# Nearest to by: raised, pharmaceutical, completes, spore, rave, ally, academic, congreve,
# Nearest to up: old, partitioning, statistically, barycenter, redirected, goodness, clouds, why,
# Nearest to when: rpgs, berry, councils, grant, feet, sent, merv, chah,
# Nearest to years: groves, seam, ribald, thirteen, target, miami, christmas, imitated,
# Nearest to between: fulfill, kvac, jurisdictions, secured, groups, fact, heavens, apart,
# Nearest to time: scholarship, singly, titled, location, radiometric, explosion, avoid, ndor,
# Nearest to event: reporters, yama, radiant, maurier, pata, protestors, transmitted, belize,
# Nearest to governor: offending, dashed, accustomed, person, characterises, burdensome, wb, hard,
# Nearest to liberal: amending, redesigned, circumference, neither, denying, degeneracy, influential, money,
# Nearest to bbc: italian, coils, eight, motivic, installations, ritually, kill, speculations,
# Nearest to file: terrifying, pluralized, carsten, spherically, setter, scribe, lahoud, nostalgic,
# Nearest to heavy: life, accelerate, disagreements, zephaniah, boney, seamonkey, switches, installments,
# Nearest to taking: hajj, conquistadores, quran, hemorrhage, concentrated, consonance, represents, senegalese,
# Nearest to bible: grandfather, experimenter, huxley, yana, newsradio, per, wortley, repetitive,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7612 0.1171 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7660 0.1197 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7361 0.1200 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6909 0.1186 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7627 0.1190 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6827 0.1196 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7060 0.1175 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7240 0.1179 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6706 0.1193 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6380 0.1183 sec/batch
# Nearest to d: guido, defection, canarian, theophylline, aboard, surviving, hydroplane, trespassing,
# Nearest to zero: eight, nine, beverages, oration, four, politician, seeking, historian,
# Nearest to by: spore, completes, raised, rave, pharmaceutical, congreve, maus, lipolysis,
# Nearest to up: statistically, partitioning, old, priori, barycenter, clouds, coincidentally, professors,
# Nearest to when: merv, rpgs, berry, chah, clicking, councils, feet, grant,
# Nearest to years: seam, ribald, imitated, groves, shameless, sams, robes, miami,
# Nearest to between: fulfill, kvac, secured, marchand, distinguishing, land, mp, jurisdictions,
# Nearest to time: singly, radiometric, scholarship, location, titled, emirs, ndor, explosion,
# Nearest to event: yama, reporters, radiant, maurier, pata, protestors, terminates, belize,
# Nearest to governor: offending, dashed, prime, wb, characterises, accustomed, burdensome, abolish,
# Nearest to liberal: amending, redesigned, degeneracy, neither, circumference, denying, endorsed, influential,
# Nearest to bbc: italian, eight, coils, motivic, freda, ritually, kill, goliath,
# Nearest to file: terrifying, lahoud, pluralized, spherically, scribe, nostalgic, carsten, specializes,
# Nearest to heavy: seamonkey, zephaniah, accelerate, life, awt, fades, disagreements, boney,
# Nearest to taking: hajj, conquistadores, quran, duo, senegalese, concentrated, consonance, hemorrhage,
# Nearest to bible: experimenter, grandfather, huxley, reggio, yana, summarizes, repetitive, entertained,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6637 0.1201 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6607 0.1181 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6244 0.1197 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6386 0.1181 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6453 0.1163 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6430 0.1214 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5842 0.0854 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5286 0.1189 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5220 0.1185 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5071 0.1164 sec/batch
# Nearest to d: laureate, eight, actor, nine, politician, pat, guido, canarian,
# Nearest to zero: eight, nine, beverages, four, oration, politician, historian, guyane,
# Nearest to by: spore, rave, waddingtons, completes, saltzman, sim, pharmaceutical, congreve,
# Nearest to up: statistically, partitioning, priori, old, coincidentally, bussard, barycenter, self,
# Nearest to when: merv, rpgs, berry, clicking, sent, chah, genevan, feet,
# Nearest to years: ribald, seam, imitated, robes, shameless, sams, groves, expectancy,
# Nearest to between: kvac, fulfill, marchand, distinguishing, jurisdictions, ludovico, land, secured,
# Nearest to time: radiometric, titled, singly, scholarship, location, emirs, ndor, audrey,
# Nearest to event: yama, radiant, maurier, reporters, pata, protestors, terminates, belize,
# Nearest to governor: offending, prime, dashed, president, wb, abolish, staind, accustomed,
# Nearest to liberal: amending, redesigned, degeneracy, neither, circumference, joined, endorsed, denying,
# Nearest to bbc: italian, eight, coils, motivic, freda, alen, livonian, goliath,
# Nearest to file: terrifying, nostalgic, spherically, online, lahoud, pluralized, specializes, rosie,
# Nearest to heavy: zephaniah, seamonkey, accelerate, boney, awt, fades, life, tweaking,
# Nearest to taking: conquistadores, quran, hajj, concentrated, consonance, duo, senegalese, connacht,
# Nearest to bible: huxley, experimenter, grandfather, prophets, reggio, summarizes, yana, wortley,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4910 0.1187 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5101 0.1156 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4678 0.1171 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5280 0.1178 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4877 0.1179 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4524 0.1175 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4568 0.1196 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3973 0.1193 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4492 0.1197 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4246 0.1198 sec/batch
# Nearest to d: guido, laureate, defection, winner, stara, canarian, capitulate, hydroplane,
# Nearest to zero: nine, eight, four, beverages, avogadro, guyane, oration, km,
# Nearest to by: spore, saltzman, completes, preset, sim, waddingtons, pharmaceutical, riddle,
# Nearest to up: statistically, partitioning, old, priori, bussard, coincidentally, barycenter, self,
# Nearest to when: merv, rpgs, sent, clicking, chah, genevan, berry, feet,
# Nearest to years: ribald, seam, expectancy, deaths, robes, malayan, sams, imitated,
# Nearest to between: fulfill, kvac, jurisdictions, land, groups, boerhaave, distinguishing, conditions,
# Nearest to time: singly, radiometric, location, titled, emirs, question, graphics, scholarship,
# Nearest to event: yama, maurier, radiant, reporters, pata, protestors, belize, hatched,
# Nearest to governor: prime, offending, abolish, dashed, president, wb, established, burdensome,
# Nearest to liberal: amending, redesigned, degeneracy, neither, joined, territorial, endorsed, bronfman,
# Nearest to bbc: italian, motivic, coils, eight, freda, kill, alen, installations,
# Nearest to file: terrifying, spherically, nostalgic, rosie, online, zelaya, specializes, lahoud,
# Nearest to heavy: seamonkey, zephaniah, tweaking, fades, boney, awt, trapdoor, hymnal,
# Nearest to taking: conquistadores, quran, duo, consonance, hajj, concentrated, represents, barlaam,
# Nearest to bible: prophets, huxley, texts, grandfather, scripture, christian, reggio, experimenter,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4547 0.1196 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4111 0.1195 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4301 0.1191 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3908 0.1203 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4218 0.1196 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4324 0.1187 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3836 0.1189 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3724 0.1189 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3903 0.1208 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3611 0.1181 sec/batch
# Nearest to d: guido, hydroplane, musashi, defection, evatt, acrobat, capitulate, theophylline,
# Nearest to zero: nine, four, eight, beverages, guyane, avogadro, oration, haar,
# Nearest to by: spore, saltzman, biotic, rave, pharmaceutical, sim, preset, widdecombe,
# Nearest to up: coincidentally, statistically, old, partitioning, priori, bussard, unsorted, agreed,
# Nearest to when: merv, feet, clicking, sent, rpgs, berry, chah, vilhelm,
# Nearest to years: ribald, expectancy, seam, deaths, sams, malayan, imitated, shameless,
# Nearest to between: boerhaave, kvac, land, fulfill, marchand, distinguishing, jurisdictions, groups,
# Nearest to time: singly, radiometric, scholarship, location, loosed, emirs, titled, conflicts,
# Nearest to event: yama, radiant, maurier, reporters, pata, hatched, protestors, belize,
# Nearest to governor: offending, prime, abolish, burdensome, president, wb, established, dashed,
# Nearest to liberal: amending, redesigned, neither, territorial, joined, endorsed, degeneracy, denying,
# Nearest to bbc: motivic, italian, coils, freda, ritually, eight, goliath, installations,
# Nearest to file: terrifying, online, spherically, nostalgic, specializes, rosie, zelaya, pluralized,
# Nearest to heavy: tweaking, zephaniah, fades, seamonkey, boney, awt, trapdoor, accelerate,
# Nearest to taking: conquistadores, quran, consonance, duo, require, barlaam, hajj, represents,
# Nearest to bible: prophets, huxley, texts, scripture, christian, grandfather, reggio, summarizes,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3805 0.1190 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3833 0.1187 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3395 0.1178 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3499 0.1164 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3919 0.1173 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3963 0.1173 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3894 0.1167 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3654 0.1183 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3395 0.1200 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3578 0.1187 sec/batch
# Nearest to d: guido, musashi, hydroplane, evatt, capitulate, theophylline, acrobat, calatrava,
# Nearest to zero: nine, eight, four, beverages, avogadro, guyane, one, eu,
# Nearest to by: saltzman, biotic, harnessing, spore, widdecombe, congreve, pharmaceutical, verdun,
# Nearest to up: old, coincidentally, statistically, priori, partitioning, bussard, rests, slows,
# Nearest to when: merv, feet, sent, rpgs, clicking, vilhelm, chah, postponing,
# Nearest to years: expectancy, ribald, seam, male, deaths, malayan, mortality, shameless,
# Nearest to between: kvac, boerhaave, land, distinguishing, baumgarten, jurisdictions, secured, fulfill,
# Nearest to time: radiometric, singly, emirs, scholarship, loosed, titled, watchman, location,
# Nearest to event: yama, maurier, radiant, reporters, pata, hatched, glu, moon,
# Nearest to governor: prime, abolish, offending, president, established, dashed, burdensome, resignation,
# Nearest to liberal: amending, neither, territorial, socialist, redesigned, endorsed, joined, denying,
# Nearest to bbc: motivic, italian, freda, coils, archive, waltzes, goliath, ritually,
# Nearest to file: online, spherically, nostalgic, terrifying, specializes, zelaya, rosie, courteous,
# Nearest to heavy: tweaking, zephaniah, seamonkey, fades, accelerate, cooled, trapdoor, awt,
# Nearest to taking: conquistadores, hajj, laia, consonance, barlaam, senegalese, centralism, duo,
# Nearest to bible: prophets, scripture, texts, christian, huxley, tanakh, reggio, grandfather,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3303 0.1218 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2912 0.1181 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3669 0.1188 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3932 0.1182 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4041 0.1181 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2770 0.1195 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2677 0.1178 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3364 0.1168 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2423 0.1186 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3252 0.1173 sec/batch
# Nearest to d: guido, laureate, mathematician, graeme, von, canarian, hydroplane, eight,
# Nearest to zero: nine, eight, four, migrant, beverages, net, one, seven,
# Nearest to by: saltzman, spore, congreve, widdecombe, biotic, harnessing, parishioners, rave,
# Nearest to up: old, coincidentally, statistically, priori, partitioning, slows, bussard, adad,
# Nearest to when: merv, feet, sent, clicking, rpgs, berry, chah, plaintiff,
# Nearest to years: expectancy, male, mortality, deaths, ribald, age, seam, birth,
# Nearest to between: kvac, boerhaave, land, distinguishing, groups, baumgarten, marchand, okinawa,
# Nearest to time: radiometric, titled, emirs, loosed, singly, artistry, probes, ladislaus,
# Nearest to event: yama, radiant, reporters, maurier, hatched, pata, moon, glu,
# Nearest to governor: prime, offending, abolish, resignation, staind, lieutenant, president, dashed,
# Nearest to liberal: amending, neither, influential, territorial, socialist, endorsed, interests, redesigned,
# Nearest to bbc: freda, livonian, motivic, italian, ritually, december, goliath, coils,
# Nearest to file: online, spherically, specializes, nostalgic, lahoud, terrifying, zelaya, courteous,
# Nearest to heavy: zephaniah, tweaking, fades, seamonkey, cooled, awt, newlyweds, accelerate,
# Nearest to taking: conquistadores, centralism, barlaam, connacht, require, cdn, laia, consonance,
# Nearest to bible: prophets, scripture, texts, christian, tanakh, huxley, grandfather, reggio,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3247 0.1187 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3302 0.1173 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3277 0.0516 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2652 0.1182 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2596 0.1180 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2096 0.1162 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2256 0.1181 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1992 0.1170 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2289 0.1178 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1911 0.1168 sec/batch
# Nearest to d: guido, laureate, hydroplane, acrobat, canarian, mathematician, von, appleseed,
# Nearest to zero: nine, eight, four, migrant, seven, five, two, avogadro,
# Nearest to by: saltzman, congreve, sim, harnessing, completes, widdecombe, ridings, spore,
# Nearest to up: old, adad, statistically, coincidentally, agreed, partitioning, bussard, petitioning,
# Nearest to when: feet, merv, sent, clicking, rpgs, chah, berry, accelerated,
# Nearest to years: expectancy, mortality, male, age, deaths, ribald, seam, birth,
# Nearest to between: kvac, boerhaave, distinguishing, land, baumgarten, groups, fulfill, marchand,
# Nearest to time: titled, radiometric, emirs, singly, ladislaus, artistry, probes, loosed,
# Nearest to event: yama, radiant, reporters, maurier, hatched, pata, moon, glu,
# Nearest to governor: prime, offending, abolish, staind, resignation, lieutenant, dashed, scouts,
# Nearest to liberal: amending, neither, territorial, socialist, endorsed, interests, influential, denying,
# Nearest to bbc: freda, installations, livonian, archive, coils, italian, homebrew, ritually,
# Nearest to file: online, specializes, spherically, lahoud, format, files, nostalgic, rosie,
# Nearest to heavy: fades, tweaking, cooled, seamonkey, zephaniah, awt, newlyweds, malfunctioning,
# Nearest to taking: conquistadores, laia, centralism, duo, ads, pleaded, messagepad, cdn,
# Nearest to bible: prophets, scripture, texts, tanakh, christian, huxley, reggio, jew,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2580 0.1183 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1941 0.1183 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2139 0.1173 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1443 0.1194 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1501 0.1203 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1588 0.1201 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.2205 0.1188 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1799 0.1190 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2063 0.1174 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1863 0.1184 sec/batch
# Nearest to d: guido, calatrava, musashi, evatt, hydroplane, acrobat, theophylline, devoiced,
# Nearest to zero: four, nine, eight, five, two, seven, migrant, one,
# Nearest to by: saltzman, sim, congreve, parishioners, harnessing, widdecombe, colossus, waddingtons,
# Nearest to up: old, statistically, coincidentally, adad, bussard, much, partitioning, slows,
# Nearest to when: feet, merv, berry, clicking, sent, bonds, chah, rpgs,
# Nearest to years: expectancy, deaths, male, mortality, age, ribald, migrant, servicemales,
# Nearest to between: kvac, boerhaave, distinguishing, marchand, baumgarten, jurisdictions, land, fuerzas,
# Nearest to time: emirs, singly, probes, loosed, radiometric, titled, location, ladislaus,
# Nearest to event: yama, reporters, radiant, maurier, hatched, pata, moon, glu,
# Nearest to governor: prime, offending, abolish, lieutenant, resignation, staind, scouts, burdensome,
# Nearest to liberal: amending, territorial, neither, socialist, endorsed, freedom, interests, influential,
# Nearest to bbc: freda, installations, archive, december, homebrew, marketed, livonian, coils,
# Nearest to file: specializes, files, lahoud, online, spherically, courteous, format, rosie,
# Nearest to heavy: fades, cooled, tweaking, seamonkey, zephaniah, newlyweds, awt, malfunctioning,
# Nearest to taking: conquistadores, laia, ads, duo, messagepad, centralism, cdn, dakuten,
# Nearest to bible: prophets, scripture, texts, tanakh, christian, reggio, huxley, grandfather,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1629 0.1192 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2226 0.1165 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1545 0.1169 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1562 0.1179 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1796 0.1178 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1881 0.1176 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1785 0.1182 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1605 0.1183 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1312 0.1181 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1700 0.1176 sec/batch
# Nearest to d: guido, calatrava, musashi, hydroplane, devoiced, prado, laureate, acrobat,
# Nearest to zero: nine, four, eight, five, two, one, migrant, seven,
# Nearest to by: saltzman, colossus, congreve, which, sim, essentially, widdecombe, biotic,
# Nearest to up: old, statistically, adad, coincidentally, nationalrat, nouvelle, mcgwire, much,
# Nearest to when: feet, merv, rpgs, clicking, sent, postponing, accelerated, berry,
# Nearest to years: expectancy, mortality, male, deaths, age, servicemales, migrant, ribald,
# Nearest to between: kvac, boerhaave, baumgarten, distinguishing, fuerzas, land, marchand, jurisdictions,
# Nearest to time: emirs, singly, probes, ladislaus, watchman, loosed, pepsico, radiometric,
# Nearest to event: yama, reporters, radiant, maurier, hatched, pata, moon, superfortress,
# Nearest to governor: prime, abolish, offending, lieutenant, scouts, resignation, staind, burdensome,
# Nearest to liberal: amending, territorial, socialist, neither, endorsed, freedom, influential, interests,
# Nearest to bbc: archive, freda, installations, december, homebrew, marketed, livonian, coils,
# Nearest to file: files, specializes, format, formats, online, lahoud, courteous, spherically,
# Nearest to heavy: fades, tweaking, seamonkey, cooled, accelerate, malfunctioning, zephaniah, awt,
# Nearest to taking: conquistadores, duo, laia, pleaded, ads, centralism, barlaam, consonance,
# Nearest to bible: prophets, tanakh, scripture, texts, christian, reggio, yana, grandfather,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1913 0.1173 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1662 0.1176 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1574 0.1166 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2096 0.1190 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1353 0.1191 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1388 0.1199 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1561 0.1197 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1472 0.1197 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1933 0.1191 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2244 0.1183 sec/batch
# Nearest to d: guido, calatrava, graeme, laureate, hydroplane, freiherr, quincey, musashi,
# Nearest to zero: nine, eight, four, five, two, one, seven, three,
# Nearest to by: which, saltzman, verdun, followed, colossus, essentially, congreve, bedroom,
# Nearest to up: old, statistically, adad, nouvelle, coincidentally, much, nationalrat, agreed,
# Nearest to when: merv, feet, berry, postponing, rpgs, sent, vilhelm, jon,
# Nearest to years: expectancy, deaths, age, male, mortality, servicemales, ribald, birth,
# Nearest to between: kvac, boerhaave, distinguishing, baumgarten, fuerzas, unions, nep, okinawa,
# Nearest to time: emirs, ladislaus, titled, probes, singly, loosed, avoid, scholarship,
# Nearest to event: yama, reporters, maurier, hatched, radiant, moon, superfortress, pata,
# Nearest to governor: prime, lieutenant, abolish, offending, resignation, scouts, parents, dashed,
# Nearest to liberal: amending, neither, territorial, influential, endorsed, freedom, socialist, interests,
# Nearest to bbc: december, archive, freda, livonian, installations, day, homebrew, ritually,
# Nearest to file: lahoud, specializes, files, courteous, format, roms, formats, online,
# Nearest to heavy: fades, cooled, tweaking, seamonkey, accelerate, malfunctioning, band, zephaniah,
# Nearest to taking: conquistadores, duo, centralism, ads, pleaded, laia, hemorrhage, senegalese,
# Nearest to bible: prophets, tanakh, scripture, texts, reggio, yana, experimenter, christian,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2223 0.1201 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1308 0.1186 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1384 0.1177 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1414 0.1176 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0379 0.1189 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1448 0.1175 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1323 0.1182 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1321 0.1179 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1293 0.0202 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1259 0.1190 sec/batch
# Nearest to d: guido, calatrava, laureate, hydroplane, bloch, freiherr, graeme, musashi,
# Nearest to zero: eight, nine, four, two, five, one, seven, three,
# Nearest to by: saltzman, which, congreve, colossus, bedroom, waddingtons, verdun, followed,
# Nearest to up: old, statistically, adad, nationalrat, nouvelle, self, unbeaten, petitioning,
# Nearest to when: feet, merv, cameraman, postponing, berry, sent, rpgs, plaintiff,
# Nearest to years: expectancy, deaths, mortality, male, age, migrant, servicemales, birth,
# Nearest to between: kvac, boerhaave, distinguishing, tunings, downfield, ultrafilter, okinawa, brevity,
# Nearest to time: probes, emirs, ladislaus, titled, loosed, hampering, watchman, radiometric,
# Nearest to event: yama, reporters, maurier, hatched, radiant, moon, superfortress, pata,
# Nearest to governor: prime, lieutenant, abolish, resignation, offending, scouts, staind, dashed,
# Nearest to liberal: amending, territorial, freedom, influential, endorsed, neither, liberals, socialist,
# Nearest to bbc: archive, december, freda, livonian, installations, day, homebrew, coils,
# Nearest to file: files, specializes, format, lahoud, roms, formats, courteous, online,
# Nearest to heavy: fades, cooled, malfunctioning, seamonkey, tweaking, band, accelerate, zephaniah,
# Nearest to taking: duo, ads, messagepad, pleaded, conquistadores, laia, centralism, cdn,
# Nearest to bible: prophets, tanakh, scripture, texts, reggio, yana, experimenter, christian,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1004 0.1197 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0709 0.1165 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1053 0.1170 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0706 0.1167 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1109 0.1183 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0210 0.1177 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0827 0.1171 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0843 0.1179 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1134 0.1171 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0515 0.1175 sec/batch
# Nearest to d: guido, calatrava, musashi, hydroplane, quincey, evatt, bloch, devoiced,
# Nearest to zero: four, nine, eight, five, two, one, seven, six,
# Nearest to by: which, saltzman, bedroom, waddingtons, colossus, followed, verdun, congreve,
# Nearest to up: old, statistically, adad, much, to, emulator, nationalrat, nouvelle,
# Nearest to when: feet, merv, postponing, berry, sent, cameraman, plaintiff, rpgs,
# Nearest to years: deaths, expectancy, male, mortality, age, servicemales, ribald, migrant,
# Nearest to between: boerhaave, kvac, distinguishing, downfield, okinawa, diversion, silting, nep,
# Nearest to time: probes, emirs, titled, ladislaus, singly, location, avoid, artistry,
# Nearest to event: yama, reporters, hatched, maurier, radiant, moon, superfortress, hank,
# Nearest to governor: prime, lieutenant, abolish, scouts, offending, parents, dashed, resignation,
# Nearest to liberal: amending, territorial, liberals, influential, socialist, freedom, neither, endorsed,
# Nearest to bbc: archive, december, installations, freda, homebrew, coils, livonian, marketed,
# Nearest to file: lahoud, files, specializes, format, formats, roms, online, tasked,
# Nearest to heavy: fades, cooled, malfunctioning, band, seamonkey, tweaking, accelerate, zephaniah,
# Nearest to taking: duo, conquistadores, ads, messagepad, pleaded, laia, senegalese, nonspecific,
# Nearest to bible: prophets, tanakh, scripture, texts, christian, reggio, yana, israelites,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0288 0.1211 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0605 0.1195 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0283 0.1181 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0446 0.1206 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0566 0.1179 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0468 0.1190 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0647 0.1193 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1039 0.1184 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0674 0.1197 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0196 0.1201 sec/batch
# Nearest to d: guido, calatrava, musashi, devoiced, evatt, hydroplane, mapsto, quincey,
# Nearest to zero: four, nine, eight, two, five, three, one, seven,
# Nearest to by: which, saltzman, colossus, essentially, sim, bedroom, followed, bijelo,
# Nearest to up: old, statistically, nouvelle, nationalrat, much, emulator, tvs, step,
# Nearest to when: feet, merv, berry, cameraman, postponing, bonds, jon, laserdisc,
# Nearest to years: deaths, male, expectancy, age, mortality, servicemales, migrant, ribald,
# Nearest to between: boerhaave, kvac, distinguishing, silting, tunings, negotiation, downfield, ultrafilter,
# Nearest to time: emirs, ladislaus, probes, titled, singly, pepsico, loosed, hampering,
# Nearest to event: yama, reporters, hatched, radiant, maurier, moon, breaks, hank,
# Nearest to governor: prime, lieutenant, scouts, abolish, offending, parents, dashed, resignation,
# Nearest to liberal: amending, territorial, influential, liberals, freedom, socialist, interests, mokhehle,
# Nearest to bbc: archive, december, installations, freda, homebrew, marketed, auteur, day,
# Nearest to file: files, lahoud, format, specializes, formats, tasked, roms, menu,
# Nearest to heavy: fades, cooled, tweaking, malfunctioning, band, seamonkey, accelerate, tomahawk,
# Nearest to taking: duo, ads, messagepad, pleaded, nonspecific, tries, dakuten, laia,
# Nearest to bible: prophets, tanakh, scripture, christian, texts, reggio, disseminated, experimenter,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0307 0.1185 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0955 0.1204 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0785 0.1188 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0877 0.1159 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0697 0.1174 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0592 0.1186 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0502 0.1189 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0457 0.1182 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0980 0.1178 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0740 0.1180 sec/batch
# Nearest to d: calatrava, guido, musashi, evatt, devoiced, hydroplane, quincey, mapsto,
# Nearest to zero: nine, four, eight, five, two, one, three, seven,
# Nearest to by: which, saltzman, colossus, essentially, verdun, followed, christianity, bijelo,
# Nearest to up: old, nouvelle, statistically, wyman, hoist, nationalrat, unbeaten, much,
# Nearest to when: merv, feet, berry, sent, postponing, cameraman, jon, chah,
# Nearest to years: deaths, expectancy, male, mortality, age, servicemales, ribald, migrant,
# Nearest to between: kvac, boerhaave, distinguishing, negotiation, baumgarten, silting, tunings, downfield,
# Nearest to time: emirs, ladislaus, probes, singly, hampering, titled, conflicts, move,
# Nearest to event: yama, reporters, hatched, maurier, radiant, moon, hank, superfortress,
# Nearest to governor: prime, lieutenant, scouts, abolish, offending, parents, resignation, burdensome,
# Nearest to liberal: amending, territorial, influential, liberals, neither, socialist, freedom, schr,
# Nearest to bbc: archive, december, freda, installations, homebrew, day, ritually, americanized,
# Nearest to file: files, formats, lahoud, format, specializes, menu, tasked, decoders,
# Nearest to heavy: fades, malfunctioning, band, cooled, tweaking, seamonkey, accelerate, tomahawk,
# Nearest to taking: duo, conquistadores, pleaded, messagepad, ads, centralism, senegalese, hemorrhage,
# Nearest to bible: prophets, tanakh, scripture, christian, texts, reggio, yana, israelites,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0461 0.1219 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0196 0.1190 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0363 0.1190 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0729 0.1186 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0892 0.1175 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1381 0.1181 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1443 0.1174 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0291 0.1177 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0419 0.1171 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0578 0.1185 sec/batch
# Nearest to d: calatrava, guido, musashi, evatt, devoiced, quincey, hydroplane, graeme,
# Nearest to zero: nine, two, four, eight, five, one, three, seven,
# Nearest to by: which, colossus, essentially, followed, saltzman, bijelo, parishioners, sim,
# Nearest to up: old, nouvelle, statistically, much, haynes, wyman, rewarded, hoist,
# Nearest to when: merv, feet, berry, cameraman, postponing, jon, laserdisc, chah,
# Nearest to years: deaths, male, mortality, expectancy, age, fertility, migrant, servicemales,
# Nearest to between: kvac, boerhaave, distinguishing, negotiation, silting, baumgarten, brevity, tunings,
# Nearest to time: ladislaus, emirs, probes, singly, hampering, titled, then, vorarlberg,
# Nearest to event: yama, reporters, hatched, radiant, maurier, moon, hank, superfortress,
# Nearest to governor: lieutenant, prime, scouts, abolish, offending, parents, resignation, wb,
# Nearest to liberal: amending, liberals, influential, neither, socialist, territorial, freedom, mokhehle,
# Nearest to bbc: december, archive, day, june, americanized, freda, livonian, ritually,
# Nearest to file: files, menu, lahoud, formats, specializes, tasked, format, decoders,
# Nearest to heavy: fades, malfunctioning, cooled, band, tweaking, accelerate, tomahawk, seamonkey,
# Nearest to taking: duo, ads, messagepad, pleaded, senegalese, laia, conquistadores, hemorrhage,
# Nearest to bible: prophets, tanakh, scripture, yana, texts, hist, reggio, conference,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9844 0.1191 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0218 0.1193 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0465 0.1199 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0414 0.1191 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0821 0.1179 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0419 0.1040 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9878 0.1175 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0002 0.1175 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9878 0.1160 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9756 0.1182 sec/batch
# Nearest to d: calatrava, guido, musashi, quincey, slovakian, hydroplane, laureate, beaconsfield,
# Nearest to zero: nine, four, eight, two, five, one, three, seven,
# Nearest to by: which, sim, saltzman, colossus, essentially, followed, bijelo, bedroom,
# Nearest to up: old, nouvelle, statistically, tvs, rewarded, haynes, barycenter, much,
# Nearest to when: merv, feet, berry, cameraman, postponing, chah, mackenzie, sent,
# Nearest to years: male, deaths, mortality, expectancy, age, migrant, fertility, servicemales,
# Nearest to between: kvac, boerhaave, distinguishing, tunings, brevity, baumgarten, le, negotiation,
# Nearest to time: ladislaus, probes, emirs, titled, singly, radiometric, hampering, started,
# Nearest to event: yama, hatched, reporters, radiant, maurier, moon, hank, breaks,
# Nearest to governor: lieutenant, prime, scouts, abolish, parents, offending, resignation, wb,
# Nearest to liberal: amending, liberals, influential, neither, territorial, socialist, mokhehle, subscribe,
# Nearest to bbc: archive, december, day, june, external, confirmed, livonian, americanized,
# Nearest to file: files, format, formats, menu, lahoud, tasked, specializes, roms,
# Nearest to heavy: fades, malfunctioning, band, cooled, accelerate, seamonkey, tomahawk, tweaking,
# Nearest to taking: ads, duo, messagepad, pleaded, senegalese, hemorrhage, laia, dakuten,
# Nearest to bible: prophets, tanakh, scripture, christian, texts, israelites, yana, reggio,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0213 0.1189 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9544 0.1195 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0018 0.1188 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0413 0.1168 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0432 0.1180 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0031 0.1197 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9376 0.1198 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9750 0.1201 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9206 0.1186 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9691 0.1197 sec/batch
# Nearest to d: calatrava, guido, musashi, devoiced, bacteriophage, hydroplane, quincey, mapsto,
# Nearest to zero: four, two, five, eight, nine, three, one, six,
# Nearest to by: which, colossus, bijelo, sim, essentially, saltzman, ns, bedroom,
# Nearest to up: old, nouvelle, haynes, statistically, rewarded, unbeaten, barycenter, tvs,
# Nearest to when: merv, feet, cameraman, berry, postponing, chah, a, laserdisc,
# Nearest to years: deaths, male, age, expectancy, mortality, migrant, servicemales, three,
# Nearest to between: kvac, boerhaave, distinguishing, silting, tunings, checkpoint, le, garciaparra,
# Nearest to time: ladislaus, emirs, probes, titled, radiometric, singly, success, hampering,
# Nearest to event: yama, hatched, reporters, radiant, maurier, moon, hank, breaks,
# Nearest to governor: lieutenant, prime, abolish, scouts, offending, parents, resignation, staind,
# Nearest to liberal: amending, liberals, undoubtedly, mokhehle, influential, freedom, socialist, subscribe,
# Nearest to bbc: archive, december, day, june, website, homebrew, news, external,
# Nearest to file: files, formats, lahoud, tasked, format, menu, specializes, gamefaqs,
# Nearest to heavy: band, cooled, fades, malfunctioning, tomahawk, accelerate, detonation, seamonkey,
# Nearest to taking: duo, ads, pleaded, messagepad, laia, cdn, senegalese, dakuten,
# Nearest to bible: prophets, tanakh, scripture, christian, texts, yana, conference, experimenter,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0032 0.1194 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0200 0.1185 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9583 0.1204 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0215 0.1181 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0047 0.1170 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9631 0.1184 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9941 0.1182 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9829 0.1166 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9827 0.1176 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9919 0.1176 sec/batch
# Nearest to d: guido, calatrava, musashi, quincey, devoiced, freiherr, hydroplane, barber,
# Nearest to zero: nine, two, four, five, eight, one, three, six,
# Nearest to by: which, colossus, bijelo, bedroom, dirkszoon, pili, saltzman, specification,
# Nearest to up: old, nouvelle, tvs, wyman, rewarded, haynes, unbeaten, barycenter,
# Nearest to when: merv, cameraman, feet, postponing, berry, a, sent, jon,
# Nearest to years: deaths, male, age, expectancy, mortality, three, ribald, migrant,
# Nearest to between: kvac, boerhaave, distinguishing, silting, le, ultrafilter, tunings, baumgarten,
# Nearest to time: ladislaus, emirs, probes, success, titled, singly, hampering, scholarship,
# Nearest to event: yama, hatched, reporters, radiant, moon, maurier, breaks, dorms,
# Nearest to governor: lieutenant, prime, scouts, abolish, offending, parents, resignation, burdensome,
# Nearest to liberal: amending, liberals, mokhehle, undoubtedly, influential, reparation, neither, subscribe,
# Nearest to bbc: december, archive, day, june, news, external, americanized, website,
# Nearest to file: files, format, formats, lahoud, menu, tasked, gamefaqs, specializes,
# Nearest to heavy: fades, malfunctioning, cooled, band, accelerate, tomahawk, seamonkey, detonation,
# Nearest to taking: duo, ads, pleaded, messagepad, cdn, dakuten, laia, hemorrhage,
# Nearest to bible: prophets, tanakh, scripture, christian, conference, yana, sceptics, redemptive,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0055 0.1184 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9649 0.1182 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9629 0.1160 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9954 0.1168 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9975 0.1196 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0069 0.1184 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9802 0.1195 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9456 0.1202 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9773 0.1190 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0491 0.1188 sec/batch
# Nearest to d: calatrava, guido, musashi, quincey, devoiced, hydroplane, evatt, barber,
# Nearest to zero: two, eight, five, four, nine, one, three, six,
# Nearest to by: which, colossus, essentially, followed, the, bijelo, specification, saltzman,
# Nearest to up: old, nouvelle, tvs, barycenter, wyman, rewarded, cardboard, much,
# Nearest to when: merv, postponing, cameraman, feet, a, sent, laserdisc, berry,
# Nearest to years: deaths, male, mortality, age, expectancy, three, fertility, servicemales,
# Nearest to between: kvac, boerhaave, silting, distinguishing, tunings, negotiation, okinawa, prefix,
# Nearest to time: ladislaus, emirs, probes, singly, scholarship, hampering, success, location,
# Nearest to event: yama, hatched, reporters, radiant, moon, maurier, breaks, slovenians,
# Nearest to governor: prime, lieutenant, scouts, abolish, offending, parents, resignation, burdensome,
# Nearest to liberal: amending, liberals, influential, mokhehle, neither, reparation, subscribe, undoubtedly,
# Nearest to bbc: december, archive, day, june, americanized, news, external, homebrew,
# Nearest to file: files, formats, lahoud, menu, format, tasked, gamefaqs, sealift,
# Nearest to heavy: malfunctioning, fades, band, cooled, tomahawk, detonation, seamonkey, overkill,
# Nearest to taking: duo, ads, pleaded, cdn, messagepad, dakuten, conquistadores, centralism,
# Nearest to bible: prophets, tanakh, scripture, conference, experimenter, redemptive, christian, yana,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9967 0.1187 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0746 0.1183 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0408 0.1178 sec/batch
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7936 0.1189 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8709 0.1198 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8524 0.1191 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8225 0.1186 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8616 0.1182 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9197 0.1185 sec/batch
# Nearest to d: calatrava, maintaining, bacteriophage, anadolu, buds, cabriolet, mapsto, devoiced,
# Nearest to zero: two, five, four, three, six, one, nine, eight,
# Nearest to by: which, the, also, in, a, of, and, general,
# Nearest to up: much, lamb, down, too, sympathizer, veer, xxxii, old,
# Nearest to when: a, before, to, cameraman, the, laserdisc, postponing, where,
# Nearest to years: zero, deaths, age, two, three, male, mortality, total,
# Nearest to between: kvac, with, negotiation, different, tunings, checkpoint, rather, fsm,
# Nearest to time: ladislaus, before, during, after, then, started, success, the,
# Nearest to event: hatched, yama, breaks, events, radiant, wallop, ongoing, gaugamela,
# Nearest to governor: lieutenant, organ, scouts, prime, offending, surat, ensign, dries,
# Nearest to liberal: liberals, mokhehle, amending, ideal, centrist, shopkeeper, subscribe, geral,
# Nearest to bbc: december, day, pbs, archive, june, itv, news, diena,
# Nearest to file: files, format, formats, lahoud, tasked, tsai, disk, menu,
# Nearest to heavy: tomahawk, band, metal, overkill, fades, malfunctioning, vapors, cooled,
# Nearest to taking: duo, ads, messagepad, redundant, dakuten, hemorrhage, clean, protestors,
# Nearest to bible: prophets, sceptics, midwest, orca, tanakh, hiker, redemptive, bookstore,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8142 0.1196 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8535 0.1177 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8614 0.1170 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8444 0.1178 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8860 0.1190 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8881 0.1162 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8509 0.1182 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8363 0.1165 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8772 0.1171 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8563 0.1189 sec/batch
# Nearest to d: calatrava, bacteriophage, maintaining, anadolu, sophisticated, buds, cabriolet, devoiced,
# Nearest to zero: two, five, three, four, nine, one, six, eight,
# Nearest to by: the, which, in, also, of, a, and, general,
# Nearest to up: lamb, sympathizer, reinforce, much, too, barycenter, down, veer,
# Nearest to when: a, to, before, the, cameraman, postponing, where, then,
# Nearest to years: zero, deaths, age, three, male, two, mortality, total,
# Nearest to between: kvac, with, different, negotiation, fsm, checkpoint, of, tunings,
# Nearest to time: ladislaus, before, during, then, after, sooner, started, respect,
# Nearest to event: hatched, yama, events, breaks, ongoing, wallop, gaugamela, commemorations,
# Nearest to governor: lieutenant, organ, prime, scouts, offending, dries, vice, ensign,
# Nearest to liberal: liberals, mokhehle, centrist, shopkeeper, amending, ideal, subscribe, geral,
# Nearest to bbc: december, day, pbs, june, archive, itv, news, uk,
# Nearest to file: files, format, formats, lahoud, archivers, menu, tasked, tsai,
# Nearest to heavy: tomahawk, metal, band, overkill, seamonkey, fades, guerin, vapors,
# Nearest to taking: duo, redundant, ads, praises, messagepad, conquistadores, cusco, hemorrhage,
# Nearest to bible: prophets, sceptics, midwest, tanakh, redemptive, bookstore, orca, hiker,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8855 0.1193 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8547 0.1203 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8166 0.1193 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8483 0.1181 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8975 0.1190 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8384 0.1182 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9661 0.1182 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9034 0.1177 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9247 0.1198 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8238 0.1190 sec/batch
# Nearest to d: calatrava, bacteriophage, anadolu, maintaining, navarro, acf, barber, francisci,
# Nearest to zero: two, five, three, one, four, six, nine, eight,
# Nearest to by: which, the, also, in, a, of, for, general,
# Nearest to up: lamb, reinforce, sympathizer, too, much, down, veer, from,
# Nearest to when: a, the, before, to, cameraman, where, then, laserdisc,
# Nearest to years: zero, two, three, male, deaths, six, five, mortality,
# Nearest to between: with, kvac, negotiation, of, the, fsm, different, tunings,
# Nearest to time: ladislaus, before, then, last, started, during, after, respect,
# Nearest to event: hatched, yama, events, breaks, ongoing, wallop, gaugamela, joke,
# Nearest to governor: lieutenant, prime, organ, scouts, dries, offending, resignation, gubernatorial,
# Nearest to liberal: liberals, mokhehle, shopkeeper, amending, conservative, ideal, subscribe, centrist,
# Nearest to bbc: day, december, june, pbs, news, archive, uk, days,
# Nearest to file: files, format, formats, lahoud, menu, archivers, tasked, tsai,
# Nearest to heavy: tomahawk, metal, band, fades, overkill, guerin, vapors, life,
# Nearest to taking: duo, ads, praises, redundant, hemorrhage, messagepad, conquistadores, cusco,
# Nearest to bible: prophets, midwest, sceptics, orca, tanakh, hiker, redemptive, bookstore,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7828 0.1181 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8559 0.1178 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8075 0.1183 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8672 0.1171 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8601 0.1177 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8378 0.1186 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8957 0.0575 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8135 0.1190 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8310 0.1178 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8273 0.1166 sec/batch
# Nearest to d: calatrava, bacteriophage, playwright, francisci, cabriolet, anadolu, navarro, writer,
# Nearest to zero: two, five, four, three, six, one, nine, eight,
# Nearest to by: which, the, a, in, also, of, and, for,
# Nearest to up: down, lamb, sympathizer, veer, too, reinforce, xxxii, much,
# Nearest to when: a, to, the, before, where, then, postponing, cameraman,
# Nearest to years: zero, deaths, male, two, mortality, age, total, six,
# Nearest to between: with, kvac, tunings, negotiation, fishery, rather, checkpoint, fsm,
# Nearest to time: ladislaus, before, sooner, after, during, started, weeks, then,
# Nearest to event: hatched, yama, events, breaks, ongoing, wallop, joke, commemorations,
# Nearest to governor: lieutenant, organ, scouts, prime, offending, rolls, ensign, dries,
# Nearest to liberal: liberals, mokhehle, amending, subscribe, shopkeeper, ideal, centrist, conservative,
# Nearest to bbc: day, december, june, pbs, days, archive, diena, uk,
# Nearest to file: files, format, formats, lahoud, archivers, saf, menu, tasked,
# Nearest to heavy: metal, tomahawk, band, overkill, fades, seamonkey, guerin, vapors,
# Nearest to taking: duo, ads, redundant, messagepad, praises, hemorrhage, protestors, dakuten,
# Nearest to bible: prophets, sceptics, midwest, orca, hiker, tanakh, redemptive, xxviii,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8395 0.1193 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8123 0.1174 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8465 0.1176 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8061 0.1183 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8483 0.1175 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8404 0.1191 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8763 0.1186 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7710 0.1192 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8200 0.1198 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8185 0.1193 sec/batch
# Nearest to d: bacteriophage, calatrava, maintaining, buds, anadolu, cabriolet, devoiced, mapsto,
# Nearest to zero: two, five, three, four, six, one, nine, eight,
# Nearest to by: which, the, a, also, in, of, for, as,
# Nearest to up: down, lamb, reinforce, sympathizer, veer, much, too, barycenter,
# Nearest to when: a, before, the, to, postponing, cameraman, where, then,
# Nearest to years: zero, deaths, two, age, male, three, six, total,
# Nearest to between: with, kvac, checkpoint, different, tunings, fishery, negotiation, fsm,
# Nearest to time: before, ladislaus, then, sooner, during, weeks, after, expected,
# Nearest to event: hatched, yama, events, breaks, wallop, ongoing, slovenians, gaugamela,
# Nearest to governor: lieutenant, organ, prime, scouts, ensign, surat, offending, vice,
# Nearest to liberal: liberals, amending, mokhehle, shopkeeper, conservative, centrist, ideal, geral,
# Nearest to bbc: day, december, pbs, june, news, itv, archive, uk,
# Nearest to file: files, format, formats, archivers, lahoud, disk, saf, tasked,
# Nearest to heavy: tomahawk, band, metal, overkill, fades, vapors, seamonkey, jun,
# Nearest to taking: duo, ads, messagepad, redundant, dakuten, protestors, barajas, praises,
# Nearest to bible: prophets, sceptics, midwest, orca, hiker, ramat, tanakh, worships,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7459 0.1205 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8248 0.1178 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8370 0.1210 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8450 0.1209 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8167 0.1206 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8706 0.1177 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8574 0.1190 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7923 0.1182 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8217 0.1183 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8434 0.1176 sec/batch
# Nearest to d: calatrava, bacteriophage, anadolu, maintaining, cabriolet, buds, acf, sophisticated,
# Nearest to zero: two, five, three, four, nine, six, one, eight,
# Nearest to by: the, which, a, also, in, of, as, for,
# Nearest to up: down, lamb, from, sympathizer, much, reinforce, too, veer,
# Nearest to when: before, a, the, to, cameraman, then, where, postponing,
# Nearest to years: zero, deaths, age, male, three, two, six, total,
# Nearest to between: kvac, with, checkpoint, negotiation, fishery, lone, fsm, tunings,
# Nearest to time: ladislaus, before, after, during, then, weeks, started, began,
# Nearest to event: hatched, events, yama, breaks, ongoing, wallop, slovenians, joke,
# Nearest to governor: lieutenant, organ, scouts, ensign, surat, prime, vice, gubernatorial,
# Nearest to liberal: liberals, mokhehle, shopkeeper, amending, ideal, centrist, conservative, subscribe,
# Nearest to bbc: december, day, pbs, itv, uk, archive, news, june,
# Nearest to file: files, format, formats, archivers, lahoud, tasked, tsai, disk,
# Nearest to heavy: tomahawk, band, overkill, fades, metal, jun, vapors, seamonkey,
# Nearest to taking: duo, ads, redundant, messagepad, barajas, dakuten, praises, is,
# Nearest to bible: prophets, midwest, sceptics, orca, ramat, hiker, worships, levantine,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9189 0.1188 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8038 0.1167 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8357 0.1183 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8553 0.1161 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8773 0.1174 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8635 0.1180 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8411 0.1173 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8726 0.1174 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8328 0.1188 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8265 0.1188 sec/batch
# Nearest to d: calatrava, bacteriophage, anadolu, maintaining, buds, vichy, acf, luncheon,
# Nearest to zero: two, five, three, four, one, eight, nine, six,
# Nearest to by: the, which, a, also, in, of, for, and,
# Nearest to up: from, reinforce, much, down, lamb, too, sympathizer, larger,
# Nearest to when: a, to, before, the, then, where, cameraman, postponing,
# Nearest to years: zero, deaths, two, age, male, three, total, four,
# Nearest to between: with, kvac, of, different, rather, negotiation, fsm, checkpoint,
# Nearest to time: ladislaus, before, then, after, expected, during, weeks, last,
# Nearest to event: hatched, events, yama, breaks, ongoing, joke, wallop, commemorations,
# Nearest to governor: lieutenant, organ, prime, vice, ensign, gubernatorial, scouts, surat,
# Nearest to liberal: liberals, mokhehle, shopkeeper, amending, ideal, dislike, conservative, subscribe,
# Nearest to bbc: december, day, uk, pbs, itv, archive, news, diena,
# Nearest to file: files, format, formats, archivers, lahoud, tsai, menu, disk,
# Nearest to heavy: metal, band, tomahawk, guerin, seamonkey, overkill, fades, vapors,
# Nearest to taking: duo, ads, redundant, barajas, praises, messagepad, cusco, dakuten,
# Nearest to bible: sceptics, midwest, prophets, hiker, orca, worships, scripture, levantine,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8867 0.1220 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8139 0.1190 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9196 0.1178 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9202 0.1174 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8904 0.1183 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8630 0.1177 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7564 0.1183 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8199 0.1178 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7242 0.1179 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8501 0.1187 sec/batch
# Nearest to d: calatrava, bacteriophage, anadolu, writer, maintaining, acf, buds, francisci,
# Nearest to zero: two, five, three, four, one, nine, six, eight,
# Nearest to by: which, the, also, a, in, of, for, as,
# Nearest to up: down, too, reinforce, from, lamb, much, denethor, sympathizer,
# Nearest to when: a, the, to, before, then, where, postponing, paramount,
# Nearest to years: zero, two, deaths, total, three, age, four, male,
# Nearest to between: with, kvac, negotiation, a, checkpoint, of, fishery, different,
# Nearest to time: ladislaus, before, expected, then, duration, started, after, last,
# Nearest to event: hatched, events, yama, joke, ongoing, breaks, wallop, commemorations,
# Nearest to governor: lieutenant, organ, prime, ensign, gubernatorial, nauru, surat, scouts,
# Nearest to liberal: liberals, mokhehle, amending, ideal, shopkeeper, dislike, conservative, geral,
# Nearest to bbc: day, december, june, uk, pbs, diena, itv, days,
# Nearest to file: files, format, formats, lahoud, archivers, tsai, tasked, menu,
# Nearest to heavy: metal, band, tomahawk, life, guerin, moranis, overkill, vapors,
# Nearest to taking: duo, redundant, ads, messagepad, dakuten, barajas, praises, satirized,
# Nearest to bible: sceptics, midwest, prophets, hiker, orca, scholarship, worships, levantine,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8592 0.1200 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8110 0.1178 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
